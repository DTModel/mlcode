# %%
import numpy as np
import os
import pandas as pd
import copy
import matplotlib.pyplot as plt   
import seaborn as sns
import psycopg2
import pickle
from sklearn.svm import SVR
import warnings
warnings.filterwarnings("ignore")

# %%
connection = psycopg2.connect(database="edw_dev", user="postgres", password="AocAvalonPG123", host="52.15.157.95",port=5432)
cursor = connection.cursor()

# %% [markdown]
# # Iova Data

# %%
data1 = pd.read_sql_query('select edw_src.patient_info.gender,edw_fact.mme_details.master_procedure,edw_fact.mme_details.patient_type,edw_fact.mme_details.physician_name,edw_fact.mme_details.age,edw_fact.mme_details.bmi,edw_fact.mme_details.mme_medication_administrated_perdayavg from edw_fact.mme_details full outer join edw_src.patient_info on edw_fact.mme_details.unique_opd_id = edw_src.patient_info.procedure_id;',con=connection)
data1.head()
# Out:
#   gender      master_procedure patient_type        physician_name  age    bmi  \
# 0      M           ARTHROSCOPY  OUT PATIENT         WOLF, BRIAN R   41  36.44
# 1      F  ARTHROSCOPY SHOULDER    INPATIENT  PATTERSON, BRENDAN M   69  37.51
# 2      M           ARTHROSCOPY  OUT PATIENT    BOLLIER, MATTHEW J   63  38.02
# 3      M          ARTHROPLASTY  OUT PATIENT    NOISEUX, NICOLAS O   65  31.68
# 4      M  ARTHROSCOPY SHOULDER  OUT PATIENT    BOLLIER, MATTHEW J   61  24.91
#
#    mme_medication_administrated_perdayavg
# 0                                   12.00
# 1                                   45.00
# 2                                   30.34
# 3                                   53.83
# 4                                   30.00

# %% [markdown]
# # Oschner Data

# %%
data = pd.read_sql_query('select o.unique_case_id,o.patient_id ,o.order_id,o.administration_date ,o.gender ,o.age ,o.bmi ,o.cpt_code ,o.inpatient_or_outpatient ,o.procedure_name ,o.attending_physician ,o.drug_name ,o.drug_type ,p.master_procedure ,o.mme_medicationadministrated from edw_fact.dw_fact_oschner as o left join edw_dim.dw_dim_procedure as p on o.fk_procedure_id = p.procedure_id  ;',con=connection)
data.head()
# Out:
#    unique_case_id patient_id   order_id administration_date gender  age  \
# 0          857405   Z1828886  310196607           15-Nov-17   MALE   64
# 1          857405   Z1828886  310196607           15-Nov-17   MALE   64
# 2          857405   Z1828886  310244036           16-Nov-17   MALE   64
# 3          857405   Z1828886  310244036           15-Nov-17   MALE   64
# 4          857405   Z1828886  310244036           16-Nov-17   MALE   64
#
#      bmi cpt_code inpatient_or_outpatient      procedure_name  \
# 0  36.65    27447               Inpatient  ARTHROPLASTY, KNEE
# 1  36.65    27447               Inpatient  ARTHROPLASTY, KNEE
# 2  36.65    27447               Inpatient  ARTHROPLASTY, KNEE
# 3  36.65    27447               Inpatient  ARTHROPLASTY, KNEE
# 4  36.65    27447               Inpatient  ARTHROPLASTY, KNEE
#
#   attending_physician                        drug_name drug_type  \
# 0               74917  HYDROMORPHONE MGML INJ UMBRELLA       INJ
# 1               74917  HYDROMORPHONE MGML INJ UMBRELLA       INJ
# 2               74917            OXYCODONE MG ORAL TAB        PO
# 3               74917            OXYCODONE MG ORAL TAB        PO
# 4               74917            OXYCODONE MG ORAL TAB        PO
#
#      master_procedure  mme_medicationadministrated
# 0  ARTHROPLASTY, KNEE                          2.6
# 1  ARTHROPLASTY, KNEE                          2.6
# 2  ARTHROPLASTY, KNEE                         75.0
# 3  ARTHROPLASTY, KNEE                         75.0
# 4  ARTHROPLASTY, KNEE                         75.0

# %% [markdown]
# # Preprocess Data

# %%
def preprocess(data1,data2):
    data1 = data1.replace('INPATIENT','IN-PATIENT')
    data1 =  data1.dropna()
    data1 = data1.drop_duplicates()
    a = list(data1[data1['bmi'] > 50].index)
    data1 = data1.drop(a)
    
    data2 =  data2.dropna()
    data2 = data2.drop_duplicates()
    data2 = data2[data2['drug_type']=='PO']
    a = list(data2[data2['bmi'] > 50].index)
    data2 = data2.drop(a)
    b = data2[data2['mme_medicationadministrated']>300].index
    data2 = data2.drop(b)
    
    data2['patient_type'] = data2['inpatient_or_outpatient'].replace(['Inpatient','Outpatient',],['IN-PATIENT','OUT PATIENT'])
    df = data2[['gender','master_procedure','patient_type','attending_physician','age','bmi','mme_medicationadministrated']]
    df['gender'] = df['gender'].replace(['MALE','FEMALE',],['M','F'])
    df = df.rename(columns={"attending_physician": "physician_name","mme_medicationadministrated":"mme_medication_administrated_perdayavg"})
    df3 = pd.concat([data1, df], axis=0)
    return data1,df,df3

# %%
data1,df,df3 = preprocess(data1,data)
df3.shape
# Out:
# (46102, 7)

# %%
data1.shape[0] + df.shape[0]
# Out:
# 46102

# %% [markdown]
# # Local Score

# %%
def local_score(df,doctor,patient_type):
    A = df[df['physician_name'] == doctor]
    B = A[A['patient_type'] == patient_type]
    B['Patient_category']= ['Old' if x>=45 else 'Adult' if 21<=x<45 else 'Young' for x in B['age']]
    B['BMI_category']= ['Under weight' if x<=18.5 else 'Normal' if 18.5<x<=24.5 else 'Over weight' for x in B['bmi']]
    C = B.groupby(['master_procedure','gender','Patient_category','BMI_category']).agg({"mme_medication_administrated_perdayavg": [ 'mean','count']})
    return C

# %% [markdown]
# # Globel Score

# %%
def globel_score(df,patient_type):
    B = df[df['patient_type'] == patient_type]
    B['Patient_category']= ['Old' if x>=45 else 'Adult' if 21<=x<45 else 'Young' for x in B['age']]
    B['BMI_category']= ['Under weight' if x<=18.5 else 'Normal' if 18.5<x<=24.5 else 'Over weight' for x in B['bmi']]
    C = B.groupby(['master_procedure','gender','Patient_category','BMI_category']).agg({"mme_medication_administrated_perdayavg": [ 'mean','count']})
    return C

# %% [markdown]
# # Doctor Score

# %%
def doctor_score(data,df3,doctor,patient_type):
    A = local_score(data,doctor,patient_type)
    proc = []
    gender = []
    pcate = []
    bcate = []
    for i in A.index:
        proc.append(i[0])
        gender.append(i[1])
        pcate.append(i[2])
        bcate.append(i[3])
    
    mean = []
    count  = []
    for i,j in zip(A[('mme_medication_administrated_perdayavg',  'mean')],A[('mme_medication_administrated_perdayavg', 'count')]):
        mean.append(i)
        count.append(j)
    
    S = pd.DataFrame({'master_procedure':proc,'gender':gender,'Patient_category':pcate,'BMI_category':bcate,'Local mean':mean,'Local count':count})
    
    B = globel_score(df3,patient_type)
    
    pproc = []
    ggender = []
    ppcate = []
    bbcate = []
    for i in B.index:
        pproc.append(i[0])
        ggender.append(i[1])
        ppcate.append(i[2])
        bbcate.append(i[3])
    
    meann = []
    countt  = []
    for i,j in zip(B[('mme_medication_administrated_perdayavg',  'mean')],B[('mme_medication_administrated_perdayavg', 'count')]):
        meann.append(i)
        countt.append(j)
    G = pd.DataFrame({'master_procedure':pproc,'gender':ggender,'Patient_category':ppcate,'BMI_category':bbcate,'Globel mean':meann,'Globel count':countt})

    D = pd.merge(S, G, on=['master_procedure','gender','Patient_category','BMI_category'], how='inner')
    
    Local_sum = {}
    globel_sum = {}
    for i in list(D['master_procedure'].unique()):
        A = D[D['master_procedure']==str(i)]
        LSUM,GSUM = A['Local count'].sum(),A['Globel count'].sum()
        Lsum = 0
        Gsum = 0
        for ind in A.index:
            a = A['Local count'][ind]
            b = A['Local mean'][ind]
            c = A['Globel count'][ind]
            d = A['Globel mean'][ind]
        
            Lsum += (a/LSUM)*b
            Gsum +=(c/GSUM)*d
        
        Local_sum[i] = Lsum
        globel_sum[i] = Gsum
        
    D['Local_Score'] = [Local_sum[i] for i in D['master_procedure']]
    D['Globel_Score'] = [globel_sum[i] for i in D['master_procedure']]
    
    D['Globel_relative_Score'] = [(j-i)/j for i,j in zip(D['Local_Score'],D['Globel_Score'])]
    D['Local_relative_Score'] = [(50-i)/50 for i in D['Local_Score']]
    
    print("Globel Score ",np.mean(list(D['Globel_relative_Score'].unique())))
    print("Local Score ",np.mean(list(D['Local_relative_Score'].unique())))
    
    return D

# %%
D = doctor_score(df,df3,'1887','OUT PATIENT')
D
# Out:
# Globel Score  0.12558177841710272
# Local Score  -0.22777742760409175
#                              master_procedure gender Patient_category  \
# 0                          ARTHROPLASTY, KNEE      F            Adult
# 1                          ARTHROPLASTY, KNEE      F              Old
# 2                          ARTHROPLASTY, KNEE      F              Old
# 3                          ARTHROPLASTY, KNEE      F              Old
# 4                          ARTHROPLASTY, KNEE      M              Old
# 5                          ARTHROPLASTY, KNEE      M              Old
# 6                            ARTHROSCOPY KNEE      F            Adult
# 7                            ARTHROSCOPY KNEE      M            Adult
# 8                            ARTHROSCOPY KNEE      M            Young
# 9   Anterior Cruciate Ligament Reconstruction      F            Adult
# 10  Anterior Cruciate Ligament Reconstruction      F            Adult
# 11  Anterior Cruciate Ligament Reconstruction      F              Old
# 12  Anterior Cruciate Ligament Reconstruction      F            Young
# 13  Anterior Cruciate Ligament Reconstruction      F            Young
# 14  Anterior Cruciate Ligament Reconstruction      M            Adult
# 15  Anterior Cruciate Ligament Reconstruction      M            Adult
# 16  Anterior Cruciate Ligament Reconstruction      M              Old
# 17  Anterior Cruciate Ligament Reconstruction      M            Young
# 18  Anterior Cruciate Ligament Reconstruction      M            Young
# 19           Arthroscopic Rotator Cuff Repair      F            Adult
# 20           Arthroscopic Rotator Cuff Repair      F            Adult
# 21           Arthroscopic Rotator Cuff Repair      F              Old
# 22           Arthroscopic Rotator Cuff Repair      F              Old
# 23           Arthroscopic Rotator Cuff Repair      M            Adult
# 24           Arthroscopic Rotator Cuff Repair      M              Old
# 25           Arthroscopic Rotator Cuff Repair      M              Old
#
#     BMI_category  Local mean  Local count  Globel mean  Globel count  \
# 0    Over weight  150.000000            4    76.628649           116
# 1         Normal  131.578947           38    83.457573           423
# 2    Over weight  110.965074          408    83.426700          5018
# 3   Under weight  121.875000            4   115.178571            14
# 4         Normal  150.000000            6    69.671053           152
# 5    Over weight  119.736842          171    81.776912          2721
# 6    Over weight   37.500000            2    56.610189            53
# 7    Over weight   37.500000            1    48.472895            38
# 8    Over weight   37.500000            3    47.132245            49
# 9         Normal   37.500000            3    63.196721            61
# 10   Over weight   64.500000           10    70.390244           205
# 11        Normal   37.500000            3    65.384615            26
# 12        Normal   37.500000            4    70.061728            81
# 13   Over weight   37.500000            1    68.254717           106
# 14        Normal   37.500000            1    85.689655            87
# 15   Over weight   79.687500            8    83.460076           263
# 16   Over weight   75.000000            1    71.084906            53
# 17        Normal   37.500000            3    74.519231           156
# 18   Over weight   37.500000           10    69.830729           192
# 19        Normal   37.500000            4    55.000000            12
# 20   Over weight   37.500000            3    58.295455            44
# 21        Normal   60.000000            7    69.391026            78
# 22   Over weight   36.513158           38    59.289366           489
# 23   Over weight   37.500000            5    67.500000            47
# 24        Normal   37.500000            8    44.663462            52
# 25   Over weight   42.254902           51    63.107861           547
#
#     Local_Score  Globel_Score  Globel_relative_Score  Local_relative_Score
# 0    115.271395     82.608258              -0.395398             -1.305428
# 1    115.271395     82.608258              -0.395398             -1.305428
# 2    115.271395     82.608258              -0.395398             -1.305428
# 3    115.271395     82.608258              -0.395398             -1.305428
# 4    115.271395     82.608258              -0.395398             -1.305428
# 5    115.271395     82.608258              -0.395398             -1.305428
# 6     37.500000     51.084214               0.265918              0.250000
# 7     37.500000     51.084214               0.265918              0.250000
# 8     37.500000     51.084214               0.265918              0.250000
# 9     52.159091     74.065041               0.295766             -0.043182
# 10    52.159091     74.065041               0.295766             -0.043182
# 11    52.159091     74.065041               0.295766             -0.043182
# 12    52.159091     74.065041               0.295766             -0.043182
# 13    52.159091     74.065041               0.295766             -0.043182
# 14    52.159091     74.065041               0.295766             -0.043182
# 15    52.159091     74.065041               0.295766             -0.043182
# 16    52.159091     74.065041               0.295766             -0.043182
# 17    52.159091     74.065041               0.295766             -0.043182
# 18    52.159091     74.065041               0.295766             -0.043182
# 19    40.625000     61.185973               0.336041              0.187500
# 20    40.625000     61.185973               0.336041              0.187500
# 21    40.625000     61.185973               0.336041              0.187500
# 22    40.625000     61.185973               0.336041              0.187500
# 23    40.625000     61.185973               0.336041              0.187500
# 24    40.625000     61.185973               0.336041              0.187500
# 25    40.625000     61.185973               0.336041              0.187500

# %%
E = doctor_score(data1,df3,'WOLF, BRIAN R','OUT PATIENT')
E
# Out:
# Globel Score  -0.06013237393773384
# Local Score  -0.08780846296063739
#       master_procedure gender Patient_category BMI_category  Local mean  \
# 0    ANT CRUC LIGAMENT      F            Adult       Normal   49.037500
# 1    ANT CRUC LIGAMENT      F            Adult  Over weight   51.171111
# 2    ANT CRUC LIGAMENT      F              Old       Normal   30.333333
# 3    ANT CRUC LIGAMENT      F              Old  Over weight   55.660000
# 4    ANT CRUC LIGAMENT      F            Young       Normal   42.311429
# ..                 ...    ...              ...          ...         ...
# 115                 VS      F            Young  Over weight   40.000000
# 116                 VS      M            Adult       Normal   57.560000
# 117                 VS      M            Adult  Over weight   45.000000
# 118                 VS      M            Young       Normal   40.320000
# 119                 VS      M            Young  Over weight   55.000000
#
#      Local count  Globel mean  Globel count  Local_Score  Globel_Score  \
# 0              8    51.352000            20    50.626154     46.815088
# 1              9    47.176552            58    50.626154     46.815088
# 2              3    35.166667             6    50.626154     46.815088
# 3              2    42.434118            17    50.626154     46.815088
# 4              7    36.567692            26    50.626154     46.815088
# ..           ...          ...           ...          ...           ...
# 115            1    40.000000             1    54.013333     54.145417
# 116            3    54.420000             4    54.013333     54.145417
# 117            1    55.604000             5    54.013333     54.145417
# 118            2    49.128000             5    54.013333     54.145417
# 119            1    66.330000             2    54.013333     54.145417
#
#      Globel_relative_Score  Local_relative_Score
# 0                -0.081407             -0.012523
# 1                -0.081407             -0.012523
# 2                -0.081407             -0.012523
# 3                -0.081407             -0.012523
# 4                -0.081407             -0.012523
# ..                     ...                   ...
# 115               0.002439             -0.080267
# 116               0.002439             -0.080267
# 117               0.002439             -0.080267
# 118               0.002439             -0.080267
# 119               0.002439             -0.080267
#
# [120 rows x 12 columns]

# %%
E = doctor_score(data1,df3,'BOLLIER, MATTHEW J','OUT PATIENT')
E
# Out:
# Globel Score  0.12137533026474126
# Local Score  0.13644489620010478
#                                       master_procedure gender  \
# 0                                    ANT CRUC LIGAMENT      F
# 1                                    ANT CRUC LIGAMENT      F
# 2                                    ANT CRUC LIGAMENT      F
# 3                                    ANT CRUC LIGAMENT      F
# 4                                    ANT CRUC LIGAMENT      F
# ..                                                 ...    ...
# 149  POSTERIOR CRUCIATE LIGAMENT (PCL) RECONSTRUCTI...      M
# 150                                Rotator Cuff Repair      F
# 151                                Rotator Cuff Repair      F
# 152                                Rotator Cuff Repair      M
# 153                              TENDON REPAIR BICEPS       M
#
#     Patient_category BMI_category  Local mean  Local count  Globel mean  \
# 0              Adult       Normal   55.420000            6    51.352000
# 1              Adult  Over weight   44.410000           21    47.176552
# 2                Old       Normal   40.000000            3    35.166667
# 3                Old  Over weight   39.980000           14    42.434118
# 4              Young       Normal   36.387273           11    36.567692
# ..               ...          ...         ...          ...          ...
# 149            Young  Over weight   73.750000            2    61.393333
# 150              Old       Normal   30.000000            2    85.227273
# 151              Old  Over weight   37.500000            2    66.295455
# 152              Old  Over weight   39.515556            3    67.901204
# 153            Adult  Over weight   20.000000            1    20.290000
#
#      Globel count  Local_Score  Globel_Score  Globel_relative_Score  \
# 0              20    43.571260     46.802010               0.069030
# 1              58    43.571260     46.802010               0.069030
# 2               6    43.571260     46.802010               0.069030
# 3              17    43.571260     46.802010               0.069030
# 4              26    43.571260     46.802010               0.069030
# ..            ...          ...           ...                    ...
# 149             3    64.304211     64.059216              -0.003825
# 150            11    36.220952     68.642295               0.472323
# 151            55    36.220952     68.642295               0.472323
# 152            72    36.220952     68.642295               0.472323
# 153             4    20.000000     20.290000               0.014293
#
#      Local_relative_Score
# 0                0.128575
# 1                0.128575
# 2                0.128575
# 3                0.128575
# 4                0.128575
# ..                    ...
# 149             -0.286084
# 150              0.275581
# 151              0.275581
# 152              0.275581
# 153              0.600000
#
# [154 rows x 12 columns]

# %%
E.shape
# Out:
# (154, 12)
